# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('../Data/PJT002_train.csv')

train.sample()
# Out:
#           id             dt_of_fr bldng_us bldng_archtctr  bldng_cnt  \
# 33759  95845  2016-09-06 00:34:45      NaN            NaN          4
#
#        bldng_ar  ttl_ar  lnd_ar dt_of_athrztn  ttl_grnd_flr  ...  mlt_us_yn  \
# 33759      17.9    17.9     0.0           NaN           1.0  ...          N
#
#       cctv_dstnc  cctv_in_100m  fr_wthr_fclt_in_100m  tbc_rtl_str_dstnc  \
# 33759        836             0                     0               7032
#
#        sft_emrgnc_bll_dstnc  ahsm_dstnc  no_tbc_zn_dstnc  bldng_cnt_in_50m  \
# 33759                 17198        1970              293                 0
#
#        fr_yn
# 33759      N
#
# [1 rows x 172 columns]

# %%
pd.DataFrame(train.columns)
# Out:
#                         0
# 0                      id
# 1                dt_of_fr
# 2                bldng_us
# 3          bldng_archtctr
# 4               bldng_cnt
# 5                bldng_ar
# 6                  ttl_ar
# 7                  lnd_ar
# 8           dt_of_athrztn
# 9            ttl_grnd_flr
# 10            ttl_dwn_flr
# 11      bldng_us_clssfctn
# 12                 tmprtr
# 13                prcpttn
# 14                wnd_spd
# 15              wnd_drctn
# 16                   hmdt
# 17    gas_engry_us_201401
# 18    ele_engry_us_201401
# 19    gas_engry_us_201402
# 20    ele_engry_us_201402
# 21    gas_engry_us_201403
# 22    ele_engry_us_201403
# 23    gas_engry_us_201404
# 24    ele_engry_us_201404
# 25    gas_engry_us_201405
# 26    ele_engry_us_201405
# 27    gas_engry_us_201406
# 28    ele_engry_us_201406
# 29    gas_engry_us_201407
# ..                    ...
# 142           lw_13101410
# 143           lw_13111010
# 144           lw_13111110
# 145           lw_13121010
# 146           lw_13121011
# 147           lw_13131010
# 148           lw_13131110
# 149           lw_13141010
# 150           lw_13141011
# 151                   jmk
# 152            rgnl_ar_nm
# 153           rgnl_ar_nm2
# 154        lnd_us_sttn_nm
# 155              rd_sd_nm
# 156                emd_nm
# 157                hm_cnt
# 158         fr_sttn_dstnc
# 159          bldng_ar_prc
# 160    fr_wthr_fclt_dstnc
# 161             fr_mn_cnt
# 162             mlt_us_yn
# 163            cctv_dstnc
# 164          cctv_in_100m
# 165  fr_wthr_fclt_in_100m
# 166     tbc_rtl_str_dstnc
# 167  sft_emrgnc_bll_dstnc
# 168            ahsm_dstnc
# 169       no_tbc_zn_dstnc
# 170      bldng_cnt_in_50m
# 171                 fr_yn
#
# [172 rows x 1 columns]

# %%
# train[:16]
# # train[137:]

# %%
train.isnull().sum()
# Out:
# id                          0
# dt_of_fr                    0
# bldng_us                27677
# bldng_archtctr          27665
# bldng_cnt                   0
# bldng_ar                    0
# ttl_ar                      0
# lnd_ar                      0
# dt_of_athrztn           27581
# ttl_grnd_flr            10210
# ttl_dwn_flr             11005
# bldng_us_clssfctn       29343
# tmprtr                     13
# prcpttn                 53629
# wnd_spd                    33
# wnd_drctn                 221
# hmdt                       22
# gas_engry_us_201401     53825
# ele_engry_us_201401     43550
# gas_engry_us_201402     53825
# ele_engry_us_201402     43550
# gas_engry_us_201403     53825
# ele_engry_us_201403     43550
# gas_engry_us_201404     53825
# ele_engry_us_201404     43550
# gas_engry_us_201405     53825
# ele_engry_us_201405     43550
# gas_engry_us_201406     53825
# ele_engry_us_201406     43550
# gas_engry_us_201407     53825
#                         ...
# lw_13101410             58916
# lw_13111010             58899
# lw_13111110             58918
# lw_13121010             58926
# lw_13121011             58926
# lw_13131010             58903
# lw_13131110             58903
# lw_13141010             58907
# lw_13141011             58908
# jmk                         0
# rgnl_ar_nm               1491
# rgnl_ar_nm2              1491
# lnd_us_sttn_nm           1776
# rd_sd_nm                 1491
# emd_nm                      4
# hm_cnt                    701
# fr_sttn_dstnc               0
# bldng_ar_prc            21895
# fr_wthr_fclt_dstnc          0
# fr_mn_cnt                  41
# mlt_us_yn                   0
# cctv_dstnc                  0
# cctv_in_100m                0
# fr_wthr_fclt_in_100m        0
# tbc_rtl_str_dstnc           0
# sft_emrgnc_bll_dstnc        0
# ahsm_dstnc                  0
# no_tbc_zn_dstnc             0
# bldng_cnt_in_50m            0
# fr_yn                       0
# Length: 172, dtype: int64

# %%
# 전기 가스 제외 나머지 칼럼
columns = ['id', 'dt_of_fr', 'bldng_us', 'bldng_archtctr', 'bldng_cnt'
           , 'bldng_ar', 'ttl_ar', 'lnd_ar', 'dt_of_athrztn', 'ttl_grnd_flr'
           , 'ttl_dwn_flr', 'bldng_us_clssfctn', 'tmprtr', 'prcpttn'
           , 'wnd_spd', 'wnd_drctn', 'hmdt', 'jmk'
           , 'fr_sttn_dstnc', 'fr_wthr_fclt_dstnc'
           , 'mlt_us_yn', 'cctv_dstnc', 'cctv_in_100m'
           , 'fr_wthr_fclt_in_100m', 'tbc_rtl_str_dstnc', 'sft_emrgnc_bll_dstnc'
           , 'ahsm_dstnc', 'no_tbc_zn_dstnc', 'bldng_cnt_in_50m', 'fr_yn'
          ]

# %%
# NULL 값 없는 칼럼 전체

# 'emd_nm', 4개
# tmprtr                   13
# wnd_spd                  33
# hmdt                     22
# emd_nm                    4
# hm_cnt                  701
# fr_mn_cnt                41
columns = ['id', 'dt_of_fr', 'bldng_cnt', 'bldng_ar', 'ttl_ar', 'lnd_ar'
           , 'jmk', 'fr_sttn_dstnc', 'fr_wthr_fclt_dstnc'
           , 'mlt_us_yn', 'cctv_dstnc', 'cctv_in_100m'
           , 'fr_wthr_fclt_in_100m', 'tbc_rtl_str_dstnc', 'sft_emrgnc_bll_dstnc'
           , 'ahsm_dstnc', 'no_tbc_zn_dstnc', 'bldng_cnt_in_50m', 'fr_yn'
          ]

df = train[columns]

# %%
df.sample()
# Out:
#           id             dt_of_fr  bldng_cnt  bldng_ar  ttl_ar  lnd_ar jmk  \
# 28348  87851  2014-06-06 11:56:20          2    121.98  121.98     0.0   전
#
#        fr_sttn_dstnc  fr_wthr_fclt_dstnc mlt_us_yn  cctv_dstnc  cctv_in_100m  \
# 28348           1098                 842         N          16             1
#
#        fr_wthr_fclt_in_100m  tbc_rtl_str_dstnc  sft_emrgnc_bll_dstnc  \
# 28348                     0                853                  3987
#
#        ahsm_dstnc  no_tbc_zn_dstnc  bldng_cnt_in_50m fr_yn
# 28348        1630             1053                 0     N

# %% [markdown]
# ## fr_yn One HOt Encoding
# 32                     3701       14444              176                10
# 33                     2173       18618              122                 0
# 35                     1721       19493              195                 1
# 36                     1998       15709              208                 0
# 38                     4405       35278              115                 0
# ...                     ...         ...              ...               ...
# 59165                  3718       24998               86                 0
# 59167                  3027       20722               59                 0
# 59168                  3128       20873               71                 0
# 59169                  1445       25333               31                 0
# 59170                 66522         609              900                 0
# 59171                  3662       25321               81                 0
# 59172                  3142       25156               34                 0
# 59173                  3131       29690              122                 0
# 59174                  2657       24084              130                 3
# 59175                  2675       20671              226                 0
# 59176                  4995       18871              426                 0
# 59177                  3988       20990               25                 0
# 59178                  3693       15854              386                 1
# 59179                  3889       14831              401                 1
# 59180                 16911        6584             2445                 0
# 59181                  2914       15434               82                 2
# 59182                  2540       14932              109                 0
# 59183                  4396       11823               68                 0
# 59184                  3767       14058              515                 0
# 59186                  4275       14199              269                 3
# 59187                  2911       15818               50                 2
# 59188                  5574        6195               50                 0
# 59191                  2874       15672              128                 0
# 59192                  4217       14439              206                 0
# 59193                  4211       12564              136                 0
# 59194                  2744       15409              160                 3
# 59195                  1805       18649               31                 0
# 59196                  2899       14666               35                 0
# 59197                  2573       14826              210                 0
# 59198                  3925       15248               19                 0
#
#       fr_yn  fire_yes
# 0         N     False
# 1         N     False
# 2         N     False
# 3         N     False
# 4         N     False
# 9         N     False
# 11        N     False
# 12        N     False
# 13        N     False
# 14        N     False
# 15        N     False
# 16        N     False
# 17        N     False
# 19        N     False
# 20        N     False
# 21        N     False
# 22        N     False
# 23        N     False
# 24        N     False
# 25        N     False
# 26        N     False
# 27        N     False
# 28        N     False
# 29        N     False
# 30        N     False
# 32        N     False
# 33        N     False
# 35        N     False
# 36        N     False
# 38        N     False
# ...     ...       ...
# 59165     N     False
# 59167     N     False
# 59168     N     False
# 59169     N     False
# 59170     N     False
# 59171     N     False
# 59172     N     False
# 59173     N     False
# 59174     N     False
# 59175     N     False
# 59176     N     False
# 59177     N     False
# 59178     N     False
# 59179     N     False
# 59180     N     False
# 59181     N     False
# 59182     N     False
# 59183     N     False
# 59184     N     False
# 59186     N     False
# 59187     N     False
# 59188     N     False
# 59191     N     False
# 59192     N     False
# 59193     N     False
# 59194     N     False
# 59195     N     False
# 59196     N     False
# 59197     N     False
# 59198     N     False
#
# [51542 rows x 20 columns]

# %% [markdown]
# # datetime Parsing
# dt_of_fr 화재 신고 일시?

# %%
df['year'] = pd.to_datetime(df['dt_of_fr']).dt.year
df['month'] = pd.to_datetime(df['dt_of_fr']).dt.month
df['day'] = pd.to_datetime(df['dt_of_fr']).dt.day
df['hour'] = pd.to_datetime(df['dt_of_fr']).dt.hour
df['minute'] = pd.to_datetime(df['dt_of_fr']).dt.minute
df['second'] = pd.to_datetime(df['dt_of_fr']).dt.second
df['dayofweek'] = pd.to_datetime(df['dt_of_fr']).dt.day_name()

df['year-month'] = df['dt_of_fr'].apply(lambda x: x[:7])

df[['dt_of_fr', 'year-month', 'year', 'month', 'day', 'dayofweek', 'hour', 'minute', 'second']].sample()
# Out:
#                   dt_of_fr year-month  year  month  day dayofweek  hour  \
# 43329  2017-12-08 01:23:08    2017-12  2017     12    8    Friday     1
#
#        minute  second
# 43329      23       8

# %% [markdown]
# ## df['fire_yes'] == True 불이 난 날

# %%
data = pd.DataFrame(df.groupby('year')['fire_yes'].sum()).reset_index()

sns.barplot(x='year', y='fire_yes', data=data, palette='GnBu_d')

# %%
data = pd.DataFrame(df.groupby('month')['fire_yes'].sum()).reset_index()

sns.barplot(x='month', y='fire_yes', data=data, palette='GnBu_d')

# %%
data = pd.DataFrame(df.groupby('year-month')['fire_yes'].sum()).reset_index()

plt.figure(figsize=[16, 5])
sns.barplot(x='year-month', y='fire_yes', data=data, palette='GnBu_d')
plt.xticks(rotation=90)
plt.show()

# %%
data = pd.DataFrame(df.groupby('dayofweek')['fire_yes'].sum()).reset_index()

index_weekday = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

plt.figure(figsize=[16, 5])
sns.barplot(x='dayofweek', y='fire_yes', data=data, order=index_weekday, palette='GnBu_d')
plt.xticks(rotation=90)
plt.show()

# %%
data = pd.DataFrame(df.groupby('hour')['fire_yes'].sum()).reset_index()

sns.barplot(x='hour', y='fire_yes', data=data, palette='GnBu_d')
plt.show()

# %%
data = pd.DataFrame(df.groupby('minute')['fire_yes'].sum()).reset_index()

plt.figure(figsize=[16, 5])
sns.barplot(x='minute', y='fire_yes', data=data, palette='GnBu_d')
plt.show()

# %%
data = pd.DataFrame(df.groupby('second')['fire_yes'].sum()).reset_index()

plt.figure(figsize=[16, 4])
sns.barplot(x='second', y='fire_yes', data=data, palette='GnBu_d')
plt.show()

# %% [markdown]
# ## df['fire_yes'] == False 불이 안난 날

# %%
data = pd.DataFrame(df[df['fire_yes'] == False].groupby('year')['id'].sum()).reset_index()

sns.barplot(x='year', y='id', data=data, palette='GnBu_d')

# %%
data = pd.DataFrame(df[df['fire_yes'] == False].groupby('month')['id'].sum()).reset_index()

sns.barplot(x='month', y='id', data=data, palette='GnBu_d')

# %%
data = pd.DataFrame(df[df['fire_yes'] == False].groupby('day')['id'].sum()).reset_index()

sns.barplot(x='day', y='id', data=data, palette='GnBu_d')

# %%
data = pd.DataFrame(df[df['fire_yes'] == False].groupby('dayofweek')['id'].sum()).reset_index()

sns.barplot(x='dayofweek', y='id', data=data, palette='GnBu_d')

# %%
data = pd.DataFrame(df[df['fire_yes'] == False].groupby('hour')['id'].sum()).reset_index()

sns.barplot(x='hour', y='id', data=data, palette='GnBu_d')

# %%
data = pd.DataFrame(df[df['fire_yes'] == False].groupby('minute')['id'].sum()).reset_index()

sns.barplot(x='minute', y='id', data=data, palette='GnBu_d')

# %%
data = pd.DataFrame(df[df['fire_yes'] == False].groupby('second')['id'].sum()).reset_index()

sns.barplot(x='second', y='id', data=data, palette='GnBu_d')

# %% [markdown]
# # correlation

# %%
df.corr()
# second -0.5 :화재발생은 0초에만 있어서
# fr_wthr_fclt_dstnc -0.16: 소방용수시설과 가까울수록 화재발생
# ahsm_dstnc 0.11: 
# fr_wthr_fclt_in_100m 0.09
# bldng_ar 0.08

# hour 0.07
# fr_sttn_dstnc -0.07
# tbc_rtl_str_dstnc -0.06
# bldng_cnt 0.05
# ttl_ar 0.05
# Out:
#                             id  bldng_cnt  bldng_ar    ttl_ar    lnd_ar  \
# lnd_ar                   -0.003896             -0.002267  ...   -0.003103
# fr_sttn_dstnc            -0.237448             -0.220333  ...    0.057742
# fr_wthr_fclt_dstnc        0.076436             -0.285666  ...   -0.272471
# cctv_dstnc               -0.188067             -0.155715  ...   -0.114840
# cctv_in_100m              1.000000              0.246822  ...    0.001951
# fr_wthr_fclt_in_100m      0.246822              1.000000  ...    0.072657
# tbc_rtl_str_dstnc        -0.229323             -0.227256  ...   -0.017208
# sft_emrgnc_bll_dstnc     -0.134099             -0.040182  ...   -0.231835
# ahsm_dstnc                0.001951              0.072657  ...    1.000000
# no_tbc_zn_dstnc          -0.166905             -0.108722  ...   -0.132781
# bldng_cnt_in_50m          0.212812              0.239189  ...   -0.090702
# fire_yes                  0.027540              0.096476  ...    0.114452
# year                      0.007794             -0.002232  ...    0.000252
# month                     0.005606              0.003773  ...   -0.002904
# day                      -0.004610             -0.003304  ...   -0.002793
# hour                     -0.001072              0.010691  ...    0.007259
# minute                   -0.009495             -0.004237  ...   -0.001430
# second                   -0.014431             -0.043929  ...   -0.058492
#
#                       no_tbc_zn_dstnc  bldng_cnt_in_50m  fire_yes      year  \
# id                           0.004541          0.001812 -0.002368 -0.002544
# bldng_cnt                    0.029456         -0.048917  0.056176  0.002270
# bldng_ar                    -0.014944         -0.009598  0.085169  0.001947
# ttl_ar                      -0.015214         -0.003122  0.059955  0.003046
# lnd_ar                      -0.004577          0.000704  0.025034  0.006845
# fr_sttn_dstnc                0.178793         -0.284051 -0.070687  0.003074
# fr_wthr_fclt_dstnc           0.001452          0.033513 -0.165280  0.001422
# cctv_dstnc                   0.101578         -0.148197 -0.029258 -0.003059
# cctv_in_100m                -0.166905          0.212812  0.027540  0.007794
# fr_wthr_fclt_in_100m        -0.108722          0.239189  0.096476 -0.002232
# tbc_rtl_str_dstnc            0.210352         -0.267521 -0.065983 -0.001057
# sft_emrgnc_bll_dstnc         0.054315         -0.079280  0.001297  0.004802
# ahsm_dstnc                  -0.132781         -0.090702  0.114452  0.000252
# no_tbc_zn_dstnc              1.000000         -0.132860 -0.046833 -0.004004
# bldng_cnt_in_50m            -0.132860          1.000000  0.023504 -0.001269
# fire_yes                    -0.046833          0.023504  1.000000 -0.003537
# year                        -0.004004         -0.001269 -0.003537  1.000000
# month                        0.001908         -0.000506 -0.020430  0.000816
# day                          0.001179         -0.005039 -0.004481 -0.001251
# hour                        -0.005590          0.005839  0.078205  0.002701
# minute                       0.005898         -0.010320 -0.005704  0.001143
# second                       0.023355         -0.014788 -0.521275  0.002877
#
#                          month       day      hour    minute    second
# id                   -0.001609 -0.000267 -0.000414 -0.012124 -0.000104
# bldng_cnt             0.000446 -0.004154  0.008258 -0.000111 -0.025870
# bldng_ar              0.003814 -0.000062  0.011439 -0.003473 -0.042919
# ttl_ar                0.002909 -0.000263  0.001096 -0.001693 -0.031276
# lnd_ar               -0.001965  0.001709  0.005195  0.001424 -0.012330
# fr_sttn_dstnc        -0.001068 -0.000498 -0.007309  0.000167  0.037959
# fr_wthr_fclt_dstnc   -0.003456  0.004841 -0.009888 -0.003842  0.084503
# cctv_dstnc           -0.004526  0.005605 -0.003888  0.001391  0.011745
# cctv_in_100m          0.005606 -0.004610 -0.001072 -0.009495 -0.014431
# fr_wthr_fclt_in_100m  0.003773 -0.003304  0.010691 -0.004237 -0.043929
# tbc_rtl_str_dstnc    -0.006470  0.006537 -0.008268  0.004900  0.037891
# sft_emrgnc_bll_dstnc  0.000351  0.005267  0.001377 -0.000027  0.003297
# ahsm_dstnc           -0.002904 -0.002793  0.007259 -0.001430 -0.058492
# no_tbc_zn_dstnc       0.001908  0.001179 -0.005590  0.005898  0.023355
# bldng_cnt_in_50m     -0.000506 -0.005039  0.005839 -0.010320 -0.014788
# fire_yes             -0.020430 -0.004481  0.078205 -0.005704 -0.521275
# year                  0.000816 -0.001251  0.002701  0.001143  0.002877
# month                 1.000000  0.011322 -0.011913 -0.001815  0.010541
# day                   0.011322  1.000000 -0.007070  0.008879  0.001949
# hour                 -0.011913 -0.007070  1.000000 -0.005887 -0.049542
# minute               -0.001815  0.008879 -0.005887  1.000000  0.001343
# second                0.010541  0.001949 -0.049542  0.001343  1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# ## fr_wthr_fclt_dstnc 소방용수시설과의 최소 거리

# %%
df['fr_wthr_fclt_dstnc'].hist(figsize=[16, 6], bins=50)

# %%
sns.catplot(hue='fire_yes', y='fr_wthr_fclt_dstnc', x='year', data=df, kind='violin')
plt.show()

# %% [markdown]
# ## ahsm_dstnc 자동심장충격기와의 거리
# 상관없을것 같은데, 외진 곳일수록 자동심장충격기도 적어서 결국 외진 곳에서 화재발생 많이 난다는 뜻?

# %%
sns.catplot(
    x='fire_yes'
            , y='ahsm_dstnc'
            , data=df
            , kind='violin')
plt.show()

# %% [markdown]
# ## fr_wthr_fclt_in_100m 반경 100m 내 소방용수시설 수
# - 100m 내 소방용수시설이 많을수록 화재발생
# - 불이 많이 나는 곳일수록 소방용수시설 많이 설치?
# - 대부분 없다

# %%
#100m 내 소방용수시설수 전체

df['fr_wthr_fclt_in_100m'].hist()

# %%
data =df.groupby('fr_wthr_fclt_in_100m')['id'].size()
print(pd.DataFrame(data))
data.plot.pie()
# Out:
#                          id
# fr_wthr_fclt_in_100m
# 0                     48609
# 1                      7668
# 2                      2168
# 3                       533
# 4                       167
# 5                        36
# 6                        11
# 7                         5
# 8                         1
# 10                        1

# %%
# 100m 내 소방용수시설수 화재발생건 only

data = pd.DataFrame(df.groupby('fr_wthr_fclt_in_100m')['fire_yes'].sum())
data
# data['fire_yes'].hist(bins=50)
# Out:
#                       fire_yes
# fr_wthr_fclt_in_100m
# 0                       5540.0
# 1                       1448.0
# 2                        485.0
# 3                        124.0
# 4                         45.0
# 5                         11.0
# 6                          2.0
# 7                          2.0
# 8                          0.0
# 10                         0.0

# %%
data = df.groupby('fr_wthr_fclt_in_100m')['fire_yes'].sum()

data.plot.pie()

# %%
data = pd.DataFrame(df.groupby('fr_wthr_fclt_in_100m')['fire_yes'].sum()).reset_index()

sns.barplot(x='fr_wthr_fclt_in_100m', y='fire_yes', data=data, palette='GnBu_d')

# %%
# 소방용수 시설 거리에 따른 화재발생 비율

data_True = pd.DataFrame(df[df['fire_yes'] == True].groupby(['fr_wthr_fclt_in_100m', 'fire_yes'])['id'].sum()).reset_index()
data_False = pd.DataFrame(df[df['fire_yes'] == False].groupby(['fr_wthr_fclt_in_100m', 'fire_yes'])['id'].sum()).reset_index()

data = data_True.merge(data_False, how='inner', on='fr_wthr_fclt_in_100m')
data['fire_ratio'] = data['id_x'].apply(lambda x: int(x)) * 100 / (data['id_x'].apply(lambda x: int(x)) + data['id_y'].apply(lambda x: int(x)))

# data
sns.barplot(x='fr_wthr_fclt_in_100m', y='fire_ratio', data=data, palette='GnBu_d')

# %% [markdown]
# ## bldng_ar 건물 건축면적

# %%
df['bldng_ar'].hist(bins=50)

# %%
sns.catplot(
    x='fire_yes'
            , y='bldng_ar'
#             , x='year'
            , data=df
            , kind='violin')
plt.show()

# %% [markdown]
# ## jmk 용도

# %%
df['jmk'].unique()
# Out:
# array(['대', '주', '잡', '종', '차', '답', '장', '양', '전', '창', '학', '목', '도',
#        '임', '철', '유', '천', '구', '체', '과', '묘', '공', '원', '사', '제', '수'],
#       dtype=object)

# %%
plt.rcParams['font.family'] = 'NanumGothic'

# %%
data = pd.DataFrame(df.groupby('jmk')['id'].sum()).reset_index()

sns.barplot(x='jmk', y='id', data=data, palette='GnBu_d')

# %%
data = pd.DataFrame(df.groupby('jmk')['fire_yes'].sum()).reset_index()

sns.barplot(x='jmk', y='fire_yes', data=data, palette='GnBu_d')

# %%
# 전체 '장' 중 화재발생 비율 계산 
data_True = pd.DataFrame(df[df['fire_yes'] == True].groupby(['jmk', 'fire_yes'])['id'].sum()).reset_index()
data_False = pd.DataFrame(df[df['fire_yes'] == False].groupby(['jmk', 'fire_yes'])['id'].sum()).reset_index()

data = data_True.merge(data_False, how='inner', on='jmk')
data['fire_ratio'] = data['id_x'].apply(lambda x: int(x)) * 100 / (data['id_x'].apply(lambda x: int(x)) + data['id_y'].apply(lambda x: int(x)))

# data
sns.barplot(x='jmk', y='fire_ratio', data=data, palette='GnBu_d')

# %% [markdown]
# ## fr_sttn_dstnc

# %%
df['fr_sttn_dstnc'].hist()

# %%
data = pd.DataFrame(df.groupby('fr_sttn_dstnc')['fire_yes'].sum()).reset_index()

sns.barplot(x='fr_sttn_dstnc', y='fire_yes', data=data, palette='GnBu_d')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-88eaece51c2c> in <module>
#       1 data = pd.DataFrame(df.groupby('fr_sttn_dstnc')['fire_yes'].sum()).reset_index()
#       2
# ----> 3 sns.barplot(x='fr_sttn_dstnc', y='fire_yes', data=data, palette='GnBu_d')
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3152         ax = plt.gca()
#    3153
# -> 3154     plotter.plot(ax, kwargs)
#    3155     return ax
#    3156
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, bar_kws)
#    1659     def plot(self, ax, bar_kws):
#    1660         """Make the plot."""
# -> 1661         self.draw_bars(ax, bar_kws)
#    1662         self.annotate_axes(ax)
#    1663         if self.orient == "h":
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in draw_bars(self, ax, kws)
#    1634                                errcolors,
#    1635                                self.errwidth,
# -> 1636                                self.capsize)
#    1637
#    1638         else:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in draw_confints(self, ax, at_group, confint, colors, errwidth, capsize, **kws)
#    1579                                                 colors):
#    1580             if self.orient == "v":
# -> 1581                 ax.plot([at, at], [ci_low, ci_high], color=color, **kws)
#    1582                 if capsize is not None:
#    1583                     ax.plot([at - capsize / 2, at + capsize / 2],
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1613             lines.append(line)
#    1614
# -> 1615         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1616         return lines
#    1617
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in autoscale_view(self, tight, scalex, scaley)
#    2427             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2428             y_stickies = sum([sticky.y for sticky in stickies], [])
# -> 2429             if self.get_xscale().lower() == 'log':
#    2430                 x_stickies = [xs for xs in x_stickies if xs > 0]
#    2431             if self.get_yscale().lower() == 'log':
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x0000020D79540598> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     302             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     303         else:
# --> 304             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     305             if not format_dict:
#     306                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <C:\Users\Minju\Anaconda3\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2052                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2053                             bbox_extra_artists=bbox_artists)
#    2054                     pad = kwargs.pop("pad_inches", None)
#    2055                     if pad is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2268
#    2269         for a in artists:
# -> 2270             bbox = a.get_tightbbox(renderer)
#    2271             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2272                 bb.append(bbox)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4401
#    4402         _bbox = mtransforms.Bbox.union(
# -> 4403             [b for b in bb if b.width != 0 or b.height != 0])
#    4404
#    4405         return _bbox
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in union(bboxes)
#     731         if not len(bboxes):
#     732             raise ValueError("'bboxes' cannot be empty")
# --> 733         x0 = np.min([bbox.xmin for bbox in bboxes])
#     734         x1 = np.max([bbox.xmax for bbox in bboxes])
#     735         y0 = np.min([bbox.ymin for bbox in bboxes])
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in <listcomp>(.0)
#     731         if not len(bboxes):
#     732             raise ValueError("'bboxes' cannot be empty")
# --> 733         x0 = np.min([bbox.xmin for bbox in bboxes])
#     734         x1 = np.max([bbox.xmax for bbox in bboxes])
#     735         y0 = np.min([bbox.ymin for bbox in bboxes])
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in xmin(self)
#     339         :attr:`xmin` is the left edge of the bounding box.
#     340         """
# --> 341         return np.min(self.get_points()[:, 0])
#     342
#     343     @property
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in amin(a, axis, out, keepdims, initial)
#    2616     """
#    2617     return _wrapreduction(a, np.minimum, 'min', axis, None, out, keepdims=keepdims,
# -> 2618                           initial=initial)
#    2619
#    2620
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:

# %%
# fr_sttn_dstnc -0.07 
data_True = pd.DataFrame(df[df['fire_yes'] == True].groupby(['fr_sttn_dstnc', 'fire_yes'])['id'].sum()).reset_index()
data_False = pd.DataFrame(df[df['fire_yes'] == False].groupby(['fr_sttn_dstnc', 'fire_yes'])['id'].sum()).reset_index()

data = data_True.merge(data_False, how='inner', on='fr_sttn_dstnc')
data['fire_ratio'] = data['id_x'].apply(lambda x: int(x)) * 100 / (data['id_x'].apply(lambda x: int(x)) + data['id_y'].apply(lambda x: int(x)))

# data
sns.barplot(x='fr_sttn_dstnc', y='fire_ratio', data=data, palette='GnBu_d')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-42ca5e713700> in <module>
#       7
#       8 # data
# ----> 9 sns.barplot(x='fr_sttn_dstnc', y='fire_ratio', data=data, palette='GnBu_d')
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3152         ax = plt.gca()
#    3153
# -> 3154     plotter.plot(ax, kwargs)
#    3155     return ax
#    3156
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, bar_kws)
#    1659     def plot(self, ax, bar_kws):
#    1660         """Make the plot."""
# -> 1661         self.draw_bars(ax, bar_kws)
#    1662         self.annotate_axes(ax)
#    1663         if self.orient == "h":
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in draw_bars(self, ax, kws)
#    1634                                errcolors,
#    1635                                self.errwidth,
# -> 1636                                self.capsize)
#    1637
#    1638         else:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in draw_confints(self, ax, at_group, confint, colors, errwidth, capsize, **kws)
#    1579                                                 colors):
#    1580             if self.orient == "v":
# -> 1581                 ax.plot([at, at], [ci_low, ci_high], color=color, **kws)
#    1582                 if capsize is not None:
#    1583                     ax.plot([at - capsize / 2, at + capsize / 2],
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1613             lines.append(line)
#    1614
# -> 1615         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1616         return lines
#    1617
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in autoscale_view(self, tight, scalex, scaley)
#    2427             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2428             y_stickies = sum([sticky.y for sticky in stickies], [])
# -> 2429             if self.get_xscale().lower() == 'log':
#    2430                 x_stickies = [xs for xs in x_stickies if xs > 0]
#    2431             if self.get_yscale().lower() == 'log':
#
# KeyboardInterrupt:

# %% [markdown]
# ## tbc_rtl_str_dstnc

# %%
df['tbc_rtl_str_dstnc'].hist()

# %%
# tbc_rtl_str_dstnc -0.06
data_True = pd.DataFrame(df[df['fire_yes'] == True].groupby(['tbc_rtl_str_dstnc', 'fire_yes'])['id'].sum()).reset_index()
data_False = pd.DataFrame(df[df['fire_yes'] == False].groupby(['tbc_rtl_str_dstnc', 'fire_yes'])['id'].sum()).reset_index()

data = data_True.merge(data_False, how='inner', on='tbc_rtl_str_dstnc')
data['fire_ratio'] = data['id_x'].apply(lambda x: int(x)) * 100 / (data['id_x'].apply(lambda x: int(x)) + data['id_y'].apply(lambda x: int(x)))

# data
sns.barplot(x='tbc_rtl_str_dstnc', y='fire_ratio', data=data, palette='GnBu_d')

# %% [markdown]
# ## bldng_cnt

# %%
df['bldng_cnt'].hist(bins=100)

# %%
df['bldng_cnt'].unique()
# Out:
# array([  3,   4,   2,  15,   1,   6,   5,   7,  12,   9,  27,   8,  10,
#         17,  14,  13,  28,  23,  62,  25,  18,  16,  21,  22,  11, 139,
#         20,  26,  49,  19,  63,  85,  31,  52,  33,  48,  24,  68,  30,
#         37,  64,  75,  32,  41,  45,  53,  36,  60,  99,  54,  35,  44,
#         46,  38,  59,  50, 125,  34,  29, 315,  61,  40, 111,  47,  51,
#         42, 114,  79,  39, 167, 132,  55,  65,  83,  43,  69, 138, 174,
#        122,  93, 223,  56,  77, 110, 705, 115, 113, 321,  57, 156, 148,
#         71,  94, 117, 210, 133], dtype=int64)

# %%
# bldng_cnt 0.05

# %% [markdown]
# ## ttl_ar

# %%
df['ttl_ar'].hist(bins=100)

# %%
# ttl_ar 0.05
